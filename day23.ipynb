# %%
pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\Users\anura\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from seaborn) (2.4.6)
# Requirement already satisfied: pandas>=1.2 in c:\Users\anura\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from seaborn) (3.0.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\Users\anura\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from seaborn) (3.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\anura\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\Users\anura\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\Users\anura\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\anura\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in C:\Users\anura\AppData\Roaming\Python\Python314\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.2)
# Requirement already satisfied: pillow>=9 in c:\Users\anura\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in c:\Users\anura\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\anura\AppData\Roaming\Python\Python314\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\Users\anura\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pandas>=1.2->seaborn) (2026.2)
# Requirement already satisfied: six>=1.5 in C:\Users\anura\AppData\Roaming\Python\Python314\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
iris = sns.load_dataset("iris")
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.describe(include="object")
# Out:
# C:\Users\anura\AppData\Local\Temp\ipykernel_31656\1209170796.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   iris.describe(include="object")
#        species
# count      150
# unique       3
# top     setosa
# freq        50

# %%
iris["species"].unique()
# Out:
# <StringArray>
# ['setosa', 'versicolor', 'virginica']
# Length: 3, dtype: str

# %%
sns.histplot(iris["petal_length"],bins=20)
plt.show()

# %% [markdown]
# # kernal density plot

# %%
sns.kdeplot(iris["petal_length"])
plt.show()

# %%
sns.scatterplot(x=iris["petal_length"],y=iris["petal_width"])
plt.show()

# %%
sns.scatterplot(x="petal_length",y="petal_width",data=iris,hue="species")
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
sns.jointplot(x="petal_length",y="petal_width",data=iris,kind="scatter")
plt.show()

# %%
sns.jointplot(x="petal_length",y="petal_width",data=iris,kind="reg")

# %%
sns.jointplot(x="petal_length",y="petal_width",data=iris,kind="kde")

# %%
sns.jointplot(x="petal_length",y="petal_width",data=iris,hue="species")
plt.plot()
# Out:
# []

# %%
sns.pairplot(data=iris,hue="species")

# %% [markdown]
# # Categorical Data

# %%
sns.countplot(x="species",data=iris,hue="species")
plt.show()

# %%
sns.boxplot(x="species",y="sepal_length",data=iris,hue="species")
plt.show()

# %%
sns.violinplot(x="species",y="sepal_length",data=iris,hue="species")
plt.show()

# %%
iris.corr(numeric_only=True)
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(iris.corr(numeric_only=True),cmap="Blues")
# Out:
# <Axes: >

# %%
sns.heatmap(iris.corr(numeric_only=True),cmap="Blues",annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # Choosing the right plot

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Multi Dimensional Plot

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 1D

# %%
sns.histplot(iris["sepal_length"],bins=20)
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
setosa = iris.loc[iris["species"]=="setosa"]
sns.boxplot(y="sepal_length",data=setosa)
# Out:
# <Axes: ylabel='sepal_length'>

# %%
sns.countplot(x="species",data=iris)
# Out:
# <Axes: xlabel='species', ylabel='count'>

# %% [markdown]
# # 2D

# %% [markdown]
# n_setosa = iris[iris['species'] == 'setosa'].shape[0]      # We are getting the number of datapoints in each species
# n_versicolor = iris[iris['species'] == 'versicolor'].shape[0]
# n_virginica = iris[iris['species'] == 'virginica'].shape[0]
#
# data = [n_setosa, n_versicolor, n_virginica]
# labels = ['setosa', 'versicolor', 'virginica']
#
# plt.pie(
#     data,
#     labels=labels,
#     autopct='%.0f%%'   # To show the portions in percentages
# )
#
# plt.show()

# %%
n_setosa = iris[iris['species'] == 'setosa'].shape[0]      # We are getting the number of datapoints in each species
n_versicolor = iris[iris['species'] == 'versicolor'].shape[0]
n_virginica = iris[iris['species'] == 'virginica'].shape[0]

data = [n_setosa, n_versicolor, n_virginica]
labels = ['setosa', 'versicolor', 'virginica']

plt.pie(
    data,
    labels=labels,
    autopct='%.0f%%'   # To show the portions in percentages
)

plt.show()

# %% [markdown]
# # 2D

# %%
sns.scatterplot(x="petal_length",y="petal_width",data=iris)
# Out:
# <Axes: xlabel='petal_length', ylabel='petal_width'>

# %%
sns.lineplot(x="petal_length",y="petal_width",data=iris)
# Out:
# <Axes: xlabel='petal_length', ylabel='petal_width'>

# %%
sns.boxplot(x="species",y="petal_length",data=iris)
# Out:
# <Axes: xlabel='species', ylabel='petal_length'>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 3D

# %%
sns.scatterplot(x="petal_length",y="petal_width",data=iris,hue="species")
plt.show()

# %%
sns.lineplot(x="petal_length",y="petal_width",data=iris,hue="species")
plt.show()

# %%
tips = sns.load_dataset("tips")

# %%
tips.shape
# Out:
# (244, 7)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.countplot(x=tips["sex"])
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
tips["day"].unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, str): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
sns.barplot(x="day",data=tips,hue="sex")
# Out:
# <Axes: xlabel='day'>

# %%
sns.countplot(x="day",data=tips,hue="sex")
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %% [markdown]
# # Two Categorical and one numerical

# %%
# Two Categorical and one numerical - day,time,total_bill
sns.barplot(x="day",y="total_bill",hue="time",data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# titanic dataset

sns.barplot(x="day",y="total_bill",hue="time",data=tips,estimator=np.mean)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>
