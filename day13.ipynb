# %% [markdown]
# ![image.png](attachment:700ce298-a297-4654-94f4-8fe2878b9611.png)

# %% [markdown]
# ![image.png](attachment:2beaee14-1015-45c4-9e52-4e8944ef463d.png)

# %% [markdown]
# ![image.png](attachment:58f34135-9a34-4edb-bc69-f6349c1fc6f1.png)

# %%
class Account:

    counter = 0

    def __init__ (self,openingBal = 0):
        Account.counter+=1
        self.id = Account.counter
        self.__bal = openingBal
        self.numsTrans = 0
        self.maxTrans = 2

    def deposit(self,amount):
        if amount >= 0 and self.numsTrans < self.maxTrans:
            self.__bal += amount
            self.numsTrans+=1

    def withdraw(self,amount):
        if amount >= 0 and self.bal >= amount and self.numTrans < self.maxTrans:
            self.__bal -= amount
            self.numTrans+=1

    def __str__(self):
        return f"Account Created Amount is {self.__bal}"


class CurrentAccount(Account):
    def __init__(self):
        super().__init__()
        self.maxTrans = 3

class SavingAccount(Account):
    pass


sal = SavingAccount()
cal = CurrentAccount()

print(sal)

sal.bal = 999999 # Not Good at all 

sal.deposit(5000)

print(sal)

sal.__bal = 8000 # Not Work

print(sal)
# Out:
# Account Created Amount is 0
# Account Created Amount is 5000
# Account Created Amount is 5000

# %% [markdown]
# # Polymorphism

# %%
# Saving Account = 3% Interset
# Current Account = No Interset


class Account:

    counter = 0

    def __init__ (self,openingBal = 0):
        Account.counter+=1
        self.id = Account.counter
        self.bal = openingBal
        self.numsTrans = 0
        self.maxTrans = 2

    def deposit(self,amount):
        if amount >= 0 and self.numsTrans < self.maxTrans:
            self.bal += amount
            self.numsTrans+=1

    def withdraw(self,amount):
        if amount >= 0 and self.bal >= amount and self.numTrans < self.maxTrans:
            self.bal -= amount
            self.numTrans+=1

    def __str__(self):
        return f"Account Created Amount is {self.bal}"



class CurrentAccount(Account):
    def __init__(self):
        super().__init__()
        self.maxTrans = 3
    def get_interest(self):
        return f"The Current Interest is {self.bal}"

class SavingAccount(Account):
    def get_interest(self):
        return f"The Current Interest is {self.bal*0.3}"


sal1 = SavingAccount()
sal1.deposit(500)
print(sal1.get_interest())
# Out:
# The Current Interest is 150.0

# %% [markdown]
# # Modules Expections

# %%
import math
print(math.sqrt(56))
print(type(math))
print(math.pi)
print(math.factorial(5))
print(math.floor(-3.4))
print(math.ceil(-3.4))
# Out:
# 7.483314773547883
# <class 'module'>
# 3.141592653589793
# 120
# -4
# -3

# %%
import random
random.seed(100)
print(random.randint(1,10)) # random integer between one to 10 inluding 1 and 10
print(random.randint(1,10)) # random integer between one to 10 inluding 1 and 10
print(random.randint(1,10)) # random integer between one to 10 inluding 1 and 10
print(random.randint(1,10)) # random integer between one to 10 inluding 1 and 10
print(random.randint(1,10)) # random integer between one to 10 inluding 1 and 10
# pseudo random behaviour
# Out:
# 3
# 8
# 8
# 3
# 7

# %%
import os
# os.getcwd()
# os.mkdir("file")
os.listdir()
# os.removedirs("file")
# os.removedirs("hello")
# Out:
# ['.git',
#  '.idea',
#  '.ipynb_checkpoints',
#  'cases',
#  'day1.ipynb',
#  'day10.ipynb',
#  'day11.ipynb',
#  'day12.ipynb',
#  'day2.ipynb',
#  'day3.ipynb',
#  'day4.ipynb',
#  'day5.ipynb',
#  'day6.ipynb',
#  'day7.ipynb',
#  'day8.ipynb',
#  'day9.ipynb',
#  'image.png',
#  'Untitled.ipynb',
#  'Week1Assignment.ipynb']

# %%
import pathlib
path = pathlib.Path("/")
print(path)
print(path.is_dir())
print(path.is_file())
path.cwd()
# Out:
# \
# True
# False
# WindowsPath('E:/ML')

# %%
help(sum)
# Out:
# Help on built-in function sum in module builtins:
#
# sum(iterable, /, start=0)
#     Return the sum of a 'start' value (default: 0) plus an iterable of numbers
#
#     When the iterable is empty, return the start value.
#     This function is intended specifically for use with numeric values and may
#     reject non-numeric types.

# %%
sum?
# Out:
# Signature: sum(iterable, /, start=0)
# Docstring:
# Return the sum of a 'start' value (default: 0) plus an iterable of numbers
#
# When the iterable is empty, return the start value.
# This function is intended specifically for use with numeric values and may
# reject non-numeric types.
# Type:      builtin_function_or_method

# %%
import numpy as np # give alises name
# Out:
# <module 'numpy' from 'C:\\Users\\anura\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\site-packages\\numpy\\__init__.py'>

# %%
# Import single fn
from math import pi
# Import all fn
from math import *
# Import multiple fn
from math import pi,sqrt
print(pi)
# Out:
# 3.141592653589793

# %%
# module is .py script
# package is collection of multiple modules
# published module => library

# %% [markdown]
# # Exception handling

# %%
__builtins__
# Out:
# <module 'builtins' (built-in)>

# %%
temp = dir(__builtins__)
count = 0
for element in temp:
    if "Error" in element:
        print(element)
        count+=1

print(count)
# Out:
# ArithmeticError
# AssertionError
# AttributeError
# BlockingIOError
# BrokenPipeError
# BufferError
# ChildProcessError
# ConnectionAbortedError
# ConnectionError
# ConnectionRefusedError
# ConnectionResetError
# EOFError
# EnvironmentError
# FileExistsError
# FileNotFoundError
# FloatingPointError
# IOError
# ImportError
# IndentationError
# IndexError
# InterruptedError
# IsADirectoryError
# KeyError
# LookupError
# MemoryError
# ModuleNotFoundError
# NameError
# NotADirectoryError
# NotImplementedError
# OSError
# OverflowError
# PermissionError
# ProcessLookupError
# RecursionError
# ReferenceError
# RuntimeError
# SyntaxError
# SystemError
# TabError
# TimeoutError
# TypeError
# UnboundLocalError
# UnicodeDecodeError
# UnicodeEncodeError
# UnicodeError
# UnicodeTranslateError
# ValueError
# WindowsError
# ZeroDivisionError
# 49

# %%
a = int(input())
b = int(input())

try:
    result = a/b
    print(result)
except:
    print("Some Error")
# Out:
#  0
#  0
# Some Error

# %%
lst = [2,0,"hello",None]
for i in lst:
    try:
        result = 5/i
        print(result)
    except ValueError as vs:
            print(vs)
    except ZeroDivisionError as zs:
            print(zs)
    except Exception as e:
            print("Error Occured",e)
    finally:
        print("Finally")
# Out:
# 2.5
# Finally
# division by zero
# Finally
# Error Occured unsupported operand type(s) for /: 'int' and 'str'
# Finally
# Error Occured unsupported operand type(s) for /: 'int' and 'NoneType'
# Finally
