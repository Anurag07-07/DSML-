# %% [markdown]
# # Function - kwargs

# %%
def person(name,age,profession,**kwargs): # kwargs must be in end
  print(kwargs)

person("AJ",21,"Something",cars="Maclaren")
# Out:
# {'cars': 'Maclaren'}

# %% [markdown]
# # Strings

# %%
name = 'Hello My name is AJ'
print(name)
print(name[0])  # Accessing character 
print(name[1])
print(name[2])
name[0] = "Hello" # String is Immutable
# Out:
# Hello My name is AJ
# H
# e
# l
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 6
#       2 print(name)
#       3 print(name[0])  # Accessing character
#       4 print(name[1])
#       5 print(name[2])
# ----> 6 name[0] = "Hello"
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# # Operations

# %%
s1 = "Hey "
s2 = "There"
s3 = s1+s2
print(s3)
print(s2*5)
# print(s1-s2) # Difference is not possible
# print('a'-'b') #There is nothing called ascii difference in py
print(chr(65)) # chr => for char value
print(ord('a')-ord('b')) # ord => for ascii value
# Out:
# Hey There
# ThereThereThereThereThere
# A
# -1

# %%
book  = "Harry potter and half blood prince"
if "Harry" in book:
  print("Yes")
else:
  print("No")

print(book.count("Harry")) # Return Occurance
print(book.find("and")) # Return Index

ans =book.replace("half","full")
print(ans)

print(book.lower())
print(book.upper())
# Out:
# Yes
# 1
# 13
# Harry potter and full blood prince
# harry potter and half blood prince
# HARRY POTTER AND HALF BLOOD PRINCE

# %%
for i in book:
  print(i,end=" ")

#  Delete the String
del book
# print(book)
# Out:
# H a r r y   p o t t e r   a n d   h a l f   b l o o d   p r i n c e
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 6
#       2   print(i,end=" ")
#       3
#       4 #  Delete the String
#       5 del book
# ----> 6 print(book)
#
# NameError: name 'book' is not defined

# %% [markdown]
# # A
# # B B
# # C C C
# # D D D D

# %%
n = int(input())

for i in range(1,n+1):
  for j in range(1,i+1):
    print(chr(64+i),end=" ")
  print()
# Out:
# A
# B B
# C C C
# D D D D
# E E E E E

# %%
s = "Reverse the Order of Book"
print(s[::-1])
a = s.split()
print(a)
s1 = "#".join(a)
print(s1)
# Out:
# kooB fo redrO eht esreveR
# ['Reverse', 'the', 'Order', 'of', 'Book']
# Reverse#the#Order#of#Book

# %%
# String Format
a = "Apple"
print("This is {}".format(a))
print(f'This is {a}')
# Out:
# This is Apple
# This is Apple
