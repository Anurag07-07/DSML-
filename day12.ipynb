# %% [markdown]
# # OOPS

# %%
class Students:
    # dunder function
    def __init__(self):
        pass

# %%
# Class Variable decleration + intialization
Students.name = "AJ"
print(Students.name)
# Out:
# AJ

# %%
stud1 = Students()
stud1.name = "AJ"
print(stud1.name)
# Out:
# AJ

# %%
class Students:
    def __init__(self,name="palceholder"):
        self.name = name
    def __str__(self): # Print the data whenever object is called
        return f"Student name is {self.name}"

s1 = Students("AJ")
print(s1)
# Out:
# Student name is AJ

# %%
class Student:
    roll_no = 0 # Static Variable
    def __init__(self,name):
        Student.roll_no+=1
        self.name = name
        self.roll = Student.roll_no
    def __str__(self):
        return f"The Student name is {self.name} and roll no is {self.roll}"
s1 = Student("AJ")
s2 = Student("BJ")
s3 = Student("CJ")
print(s1)
print(s2)
print(s3)
# Out:
# The Student name is AJ and roll no is 1
# The Student name is BJ and roll no is 2
# The Student name is CJ and roll no is 3

# %% [markdown]
# ![image.png](attachment:4a5d71c1-69da-419b-937a-66eb51bd3265.png)

# %%
class Account:
    counter = 0
    def __init__(self,opening_bal=0):
        Account.counter+=1
        self.id = Account.counter
        self.bal = opening_bal
        self.trans = 1
        self.max_trans = 5
    def __str__(self):
        return "The User {} has {} amount of Money".format(self.id,self.bal)

    def __repr__(self): #  for extra use
        return "Object Created"

    def deposit(self,amount):
        if amount>0 and self.trans<=self.max_trans:
            self.bal+=amount
            self.trans+=1
            return "Money Added"
        else:
            return "Money not added"
    
    def withdraw(self,amount):
        if amount > 0 and amount <= self.bal and self.trans<=self.max_trans: 
            self.bal-=amount
            self.trans-=1
            return True
        else:
            return False

u1 = Account(100)
u2 = Account()

# print(u1)
print(u2.withdraw(565))
print(u2.__repr__())
# Out:
# False
# Object Created

# %% [markdown]
# # Inheritance

# %%
class SavingAccount(Account):
    def __init__(self,opening_bal,max_transaction):
        super().__init__(opening_bal)
        self.max_transaction = max_transaction

        
s1 = SavingAccount(500000,150)
print(s1.deposit(5))
print(s1.deposit(5))
print(s1.deposit(5))
print(s1.deposit(5))
print(s1.deposit(5))
print(s1.deposit(5))
print(s1.deposit(5))
print(s1.deposit(5))
print(s1.bal)
# Out:
# Money Added
# Money Added
# Money Added
# Money Added
# Money Added
# Money not added
# Money not added
# Money not added
# 500025

# %% [markdown]
# ![image.png](attachment:7446abce-a48b-4569-a205-cc3071fedc0b.png)

# %% [markdown]
# # Polymorphism

# %% [markdown]
# ![image.png](attachment:3601ee37-d55a-41fa-a1ef-55fd0a852d04.png)
