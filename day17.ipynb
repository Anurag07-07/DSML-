# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
img = np.array(plt.imread("a.png"))
plt.imshow(img)

# %%
img.ndim
# Out:
# 3

# %%
img.shape
# Out:
# (1079, 1919, 4)

# %%
img_r,img_g,img_b = img.copy(),img.copy(),img.copy()

# %%
img_g[:,:,(0,2)] = 0

# %%
plt.imshow(img_g)

# %%
img_r[:,:,(1,2)] = 0

# %%
plt.imshow(img_r)

# %%
img_b[:,:,(0,1)] = 0
plt.imshow(img_b)

# %%
cm = plt.imread("b.jpg")
plt.imshow(cm)

# %%
img2 = np.array(cm)

img3 =np.transpose(img2,(1,0,2))  # row to col and col to row

plt.imshow(img3)

# %%
img3.shape
# Out:
# (736, 1307, 3)

# %%
img4 = img3[256:600,100:800,:]
plt.imshow(img4)
