# %%
import pandas as pd

# %%
df = pd.read_csv("gapminder_data_graphs.csv") # Tabular Data

# %%
df
# Out:
#           country continent  year  life_exp  hdi_index  co2_consump     gdp  \
# 0     Afghanistan      Asia  1998      53.3      0.344       0.0522     NaN
# 1     Afghanistan      Asia  1999      54.7      0.348       0.0402     NaN
# 2     Afghanistan      Asia  2000      54.7      0.350       0.0370     NaN
# 3     Afghanistan      Asia  2001      54.8      0.353       0.0376     NaN
# 4     Afghanistan      Asia  2002      55.5      0.384       0.0471   333.0
# ...           ...       ...   ...       ...        ...          ...     ...
# 3670     Zimbabwe    Africa  2014      58.0      0.547       0.8810  1440.0
# 3671     Zimbabwe    Africa  2015      58.6      0.553       0.8810  1450.0
# 3672     Zimbabwe    Africa  2016      59.2      0.558       0.7710  1430.0
# 3673     Zimbabwe    Africa  2017      59.9      0.563       0.8450  1480.0
# 3674     Zimbabwe    Africa  2018      60.6      0.569       0.8500  1510.0
#
#       services
# 0         24.4
# 1         24.6
# 2         24.7
# 3         24.7
# 4         25.6
# ...        ...
# 3670      25.4
# 3671      25.7
# 3672      26.1
# 3673      26.6
# 3674      27.2
#
# [3675 rows x 8 columns]

# %%
type(df)
# Out:
# pandas.DataFrame

# %%
df["country"] # to get the country from dictionary
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 3670       Zimbabwe
# 3671       Zimbabwe
# 3672       Zimbabwe
# 3673       Zimbabwe
# 3674       Zimbabwe
# Name: country, Length: 3675, dtype: str

# %%
type(df["country"]) 
# dataframe is matrix like something
# series is 1 D vector like something
# Out:
# pandas.Series

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3675 entries, 0 to 3674
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   country      3675 non-null   str
#  1   continent    3675 non-null   str
#  2   year         3675 non-null   int64
#  3   life_exp     3675 non-null   float64
#  4   hdi_index    3563 non-null   float64
#  5   co2_consump  3671 non-null   float64
#  6   gdp          3633 non-null   float64
#  7   services     3675 non-null   float64
# dtypes: float64(5), int64(1), str(2)
# memory usage: 229.8 KB

# %%
# Top 5 Element
df.head()
# Top 15 Element
df.head(15)
# Out:
#         country continent  year  life_exp  hdi_index  co2_consump    gdp  \
# 0   Afghanistan      Asia  1998      53.3      0.344       0.0522    NaN
# 1   Afghanistan      Asia  1999      54.7      0.348       0.0402    NaN
# 2   Afghanistan      Asia  2000      54.7      0.350       0.0370    NaN
# 3   Afghanistan      Asia  2001      54.8      0.353       0.0376    NaN
# 4   Afghanistan      Asia  2002      55.5      0.384       0.0471  333.0
# 5   Afghanistan      Asia  2003      56.5      0.393       0.0509  346.0
# 6   Afghanistan      Asia  2004      57.1      0.409       0.0368  336.0
# 7   Afghanistan      Asia  2005      57.6      0.418       0.0515  360.0
# 8   Afghanistan      Asia  2006      58.0      0.429       0.0622  368.0
# 9   Afghanistan      Asia  2007      58.5      0.447       0.0838  409.0
# 10  Afghanistan      Asia  2008      59.2      0.447       0.1520  415.0
# 11  Afghanistan      Asia  2009      59.9      0.460       0.2380  492.0
# 12  Afghanistan      Asia  2010      60.5      0.472       0.2900  547.0
# 13  Afghanistan      Asia  2011      61.0      0.477       0.4060  533.0
# 14  Afghanistan      Asia  2012      61.4      0.489       0.3450  580.0
#
#     services
# 0       24.4
# 1       24.6
# 2       24.7
# 3       24.7
# 4       25.6
# 5       25.9
# 6       26.1
# 7       26.5
# 8       26.9
# 9       27.7
# 10      28.2
# 11      29.5
# 12      30.7
# 13      31.7
# 14      32.8

# %%
#Top 15 bottom
df.tail(15)
# Out:
#        country continent  year  life_exp  hdi_index  co2_consump     gdp  \
# 3660  Zimbabwe    Africa  2004      46.4      0.411        0.785  1210.0
# 3661  Zimbabwe    Africa  2005      46.8      0.411        0.887  1140.0
# 3662  Zimbabwe    Africa  2006      47.4      0.414        0.853  1090.0
# 3663  Zimbabwe    Africa  2007      48.2      0.421        0.803  1040.0
# 3664  Zimbabwe    Africa  2008      48.9      0.422        0.624   850.0
# 3665  Zimbabwe    Africa  2009      50.2      0.458        0.441   941.0
# 3666  Zimbabwe    Africa  2010      52.3      0.482        0.607  1110.0
# 3667  Zimbabwe    Africa  2011      54.4      0.499        0.737  1250.0
# 3668  Zimbabwe    Africa  2012      56.0      0.525        0.587  1430.0
# 3669  Zimbabwe    Africa  2013      57.2      0.537        0.872  1440.0
# 3670  Zimbabwe    Africa  2014      58.0      0.547        0.881  1440.0
# 3671  Zimbabwe    Africa  2015      58.6      0.553        0.881  1450.0
# 3672  Zimbabwe    Africa  2016      59.2      0.558        0.771  1430.0
# 3673  Zimbabwe    Africa  2017      59.9      0.563        0.845  1480.0
# 3674  Zimbabwe    Africa  2018      60.6      0.569        0.850  1510.0
#
#       services
# 3660      26.2
# 3661      25.8
# 3662      25.4
# 3663      25.2
# 3664      24.4
# 3665      24.8
# 3666      25.2
# 3667      25.0
# 3668      25.4
# 3669      25.3
# 3670      25.4
# 3671      25.7
# 3672      26.1
# 3673      26.6
# 3674      27.2

# %%
df.shape # rows and  columns
# Out:
# (3675, 8)

# %%
df.describe() # work on numerical data
# Out:
#               year     life_exp    hdi_index  co2_consump            gdp  \
# count  3675.000000  3675.000000  3563.000000  3671.000000    3633.000000
# mean   2008.000000    69.849306     0.674864     4.712731   11966.053675
# std       6.056125     8.886563     0.164834     6.567435   17105.787953
# min    1998.000000    32.500000     0.255000     0.015900     238.000000
# 25%    2003.000000    63.900000     0.537500     0.560500    1470.000000
# 50%    2008.000000    71.700000     0.699000     2.250000    4280.000000
# 75%    2013.000000    76.400000     0.805000     6.615000   13600.000000
# max    2018.000000    84.800000     0.956000    67.100000  105000.000000
#
#           services
# count  3675.000000
# mean     51.248705
# std      18.312501
# min       5.590000
# 25%      37.600000
# 50%      52.900000
# 75%      65.700000
# max      88.500000

# %%
df.describe(include="object")
# Out:
# C:\Users\anura\AppData\Local\Temp\ipykernel_4908\702825166.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.describe(include="object")
#             country continent
# count          3675      3675
# unique          175         6
# top     Afghanistan    Africa
# freq             21      1071

# %% [markdown]
# # Column Operation

# %%
df.columns # know the Columns
# Out:
# Index(['country', 'continent', 'year', 'life_exp', 'hdi_index', 'co2_consump',
#        'gdp', 'services'],
#       dtype='str')

# %%
df.keys()
# Out:
# Index(['country', 'continent', 'year', 'life_exp', 'hdi_index', 'co2_consump',
#        'gdp', 'services'],
#       dtype='str')

# %% [markdown]
# # Specialized Dict

# %%
df["country"]
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 3670       Zimbabwe
# 3671       Zimbabwe
# 3672       Zimbabwe
# 3673       Zimbabwe
# 3674       Zimbabwe
# Name: country, Length: 3675, dtype: str

# %%
df[["country","continent"]]
# Out:
#           country continent
# 0     Afghanistan      Asia
# 1     Afghanistan      Asia
# 2     Afghanistan      Asia
# 3     Afghanistan      Asia
# 4     Afghanistan      Asia
# ...           ...       ...
# 3670     Zimbabwe    Africa
# 3671     Zimbabwe    Africa
# 3672     Zimbabwe    Africa
# 3673     Zimbabwe    Africa
# 3674     Zimbabwe    Africa
#
# [3675 rows x 2 columns]

# %%
# Want all Unique country 
df["country"].unique()
# Out:
# <StringArray>
# [         'Afghanistan',              'Albania',              'Algeria',
#                'Angola',            'Argentina',              'Armenia',
#             'Australia',              'Austria',           'Azerbaijan',
#               'Bahamas',
#  ...
#  'United Arab Emirates',       'United Kingdom',        'United States',
#               'Uruguay',           'Uzbekistan',              'Vanuatu',
#               'Vietnam',                'Yemen',               'Zambia',
#              'Zimbabwe']
# Length: 175, dtype: str

# %%
# How manytimes particular country appear
df["country"].value_counts() # This is Series 1st col is indexes or keys
# Out:
# country
# Afghanistan    21
# Albania        21
# Algeria        21
# Angola         21
# Argentina      21
#                ..
# Vanuatu        21
# Vietnam        21
# Yemen          21
# Zambia         21
# Zimbabwe       21
# Name: count, Length: 175, dtype: int64

# %%
df["country"].value_counts().index
# Out:
# Index(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina', 'Armenia',
#        'Australia', 'Austria', 'Azerbaijan', 'Bahamas',
#        ...
#        'United Arab Emirates', 'United Kingdom', 'United States', 'Uruguay',
#        'Uzbekistan', 'Vanuatu', 'Vietnam', 'Yemen', 'Zambia', 'Zimbabwe'],
#       dtype='str', name='country', length=175)

# %%
# Rename a col 
df.rename({"country":"Country"},axis=1)
# Out:
#           Country continent  year  life_exp  hdi_index  co2_consump     gdp  \
# 0     Afghanistan      Asia  1998      53.3      0.344       0.0522     NaN
# 1     Afghanistan      Asia  1999      54.7      0.348       0.0402     NaN
# 2     Afghanistan      Asia  2000      54.7      0.350       0.0370     NaN
# 3     Afghanistan      Asia  2001      54.8      0.353       0.0376     NaN
# 4     Afghanistan      Asia  2002      55.5      0.384       0.0471   333.0
# ...           ...       ...   ...       ...        ...          ...     ...
# 3670     Zimbabwe    Africa  2014      58.0      0.547       0.8810  1440.0
# 3671     Zimbabwe    Africa  2015      58.6      0.553       0.8810  1450.0
# 3672     Zimbabwe    Africa  2016      59.2      0.558       0.7710  1430.0
# 3673     Zimbabwe    Africa  2017      59.9      0.563       0.8450  1480.0
# 3674     Zimbabwe    Africa  2018      60.6      0.569       0.8500  1510.0
#
#       services
# 0         24.4
# 1         24.6
# 2         24.7
# 3         24.7
# 4         25.6
# ...        ...
# 3670      25.4
# 3671      25.7
# 3672      26.1
# 3673      26.6
# 3674      27.2
#
# [3675 rows x 8 columns]

# %%
df
# Out:
#           Country  year  life_exp  hdi_index  co2_consump     gdp  services  \
# 0     Afghanistan  1998      53.3      0.344       0.0522     NaN      24.4
# 1     Afghanistan  1999      54.7      0.348       0.0402     NaN      24.6
# 2     Afghanistan  2000      54.7      0.350       0.0370     NaN      24.7
# 3     Afghanistan  2001      54.8      0.353       0.0376     NaN      24.7
# 4     Afghanistan  2002      55.5      0.384       0.0471   333.0      25.6
# ...           ...   ...       ...        ...          ...     ...       ...
# 3670     Zimbabwe  2014      58.0      0.547       0.8810  1440.0      25.4
# 3671     Zimbabwe  2015      58.6      0.553       0.8810  1450.0      25.7
# 3672     Zimbabwe  2016      59.2      0.558       0.7710  1430.0      26.1
# 3673     Zimbabwe  2017      59.9      0.563       0.8450  1480.0      26.6
# 3674     Zimbabwe  2018      60.6      0.569       0.8500  1510.0      27.2
#
#       custom
# 0          0
# 1          1
# 2          2
# 3          3
# 4          4
# ...      ...
# 3670    3670
# 3671    3671
# 3672    3672
# 3673    3673
# 3674    3674
#
# [3675 rows x 8 columns]

# %%
# Rename a col 
df.rename({"Country":"country"},axis=1,inplace=True) # make change in original Dataframe

# %%
df.country # attribute way of accessing  \\Not Recommanded
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 3670       Zimbabwe
# 3671       Zimbabwe
# 3672       Zimbabwe
# 3673       Zimbabwe
# 3674       Zimbabwe
# Name: country, Length: 3675, dtype: str

# %%
# How to drop particular column
df.drop("continent",axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[56], line 2
#       1 # How to drop particular column
# ----> 2 df.drop("continent",axis=1)
#
# File c:\Users\anura\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\frame.py:6300, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6296                 weight  250.0   150.0
#    6297         falcon  speed   320.0   250.0
#    6298                 weight  1.0     0.8
#    6299         """
# -> 6300         return super().drop(
#    6301             labels=labels,
#    6302             axis=axis,
#    6303             index=index,
#
# File c:\Users\anura\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\generic.py:4644, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4640         obj = self
#    4641
#    4642         for axis, labels in axes.items():
#    4643             if labels is not None:
# -> 4644                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4645
#    4646         if inplace:
#    4647             self._update_inplace(obj)
#
# File c:\Users\anura\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\generic.py:4686, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4682                 if not isinstance(axis, MultiIndex):
#    4683                     raise AssertionError("axis must be a MultiIndex")
#    4684                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4685             else:
# -> 4686                 new_axis = axis.drop(labels, errors=errors)
#    4687             indexer = axis.get_indexer(new_axis)
#    4688
#    4689         # Case for non-unique axis
#
# File c:\Users\anura\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\indexes\base.py:7268, in Index.drop(self, labels, errors)
#    7266 if mask.any():
#    7267     if errors != "ignore":
# -> 7268         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7269     indexer = indexer[~mask]
#    7270 return self.delete(indexer)
#
# KeyError: "['continent'] not found in axis"

# %%
df
# Out:
#           Country  year  life_exp  hdi_index  co2_consump     gdp  services
# 0     Afghanistan  1998      53.3      0.344       0.0522     NaN      24.4
# 1     Afghanistan  1999      54.7      0.348       0.0402     NaN      24.6
# 2     Afghanistan  2000      54.7      0.350       0.0370     NaN      24.7
# 3     Afghanistan  2001      54.8      0.353       0.0376     NaN      24.7
# 4     Afghanistan  2002      55.5      0.384       0.0471   333.0      25.6
# ...           ...   ...       ...        ...          ...     ...       ...
# 3670     Zimbabwe  2014      58.0      0.547       0.8810  1440.0      25.4
# 3671     Zimbabwe  2015      58.6      0.553       0.8810  1450.0      25.7
# 3672     Zimbabwe  2016      59.2      0.558       0.7710  1430.0      26.1
# 3673     Zimbabwe  2017      59.9      0.563       0.8450  1480.0      26.6
# 3674     Zimbabwe  2018      60.6      0.569       0.8500  1510.0      27.2
#
# [3675 rows x 7 columns]

# %%
# How to drop particular column
df.drop("continent",axis=1,inplace=True) # To make parmanent change

# %%
# How to add the new column 
# add population*gdp_cap
df["total_gdp"] = df["gdp"]*1000

# %%
df
# Out:
#           Country  year  life_exp  hdi_index  co2_consump     gdp  services
# 0     Afghanistan  1998      53.3      0.344       0.0522     NaN      24.4
# 1     Afghanistan  1999      54.7      0.348       0.0402     NaN      24.6
# 2     Afghanistan  2000      54.7      0.350       0.0370     NaN      24.7
# 3     Afghanistan  2001      54.8      0.353       0.0376     NaN      24.7
# 4     Afghanistan  2002      55.5      0.384       0.0471   333.0      25.6
# ...           ...   ...       ...        ...          ...     ...       ...
# 3670     Zimbabwe  2014      58.0      0.547       0.8810  1440.0      25.4
# 3671     Zimbabwe  2015      58.6      0.553       0.8810  1450.0      25.7
# 3672     Zimbabwe  2016      59.2      0.558       0.7710  1430.0      26.1
# 3673     Zimbabwe  2017      59.9      0.563       0.8450  1480.0      26.6
# 3674     Zimbabwe  2018      60.6      0.569       0.8500  1510.0      27.2
#
# [3675 rows x 7 columns]

# %%
df["custom"] = [i for i in range(3675)]

# %%
df
# Out:
#           Country  year  life_exp  hdi_index  co2_consump     gdp  services  \
# 0     Afghanistan  1998      53.3      0.344       0.0522     NaN      24.4
# 1     Afghanistan  1999      54.7      0.348       0.0402     NaN      24.6
# 2     Afghanistan  2000      54.7      0.350       0.0370     NaN      24.7
# 3     Afghanistan  2001      54.8      0.353       0.0376     NaN      24.7
# 4     Afghanistan  2002      55.5      0.384       0.0471   333.0      25.6
# ...           ...   ...       ...        ...          ...     ...       ...
# 3670     Zimbabwe  2014      58.0      0.547       0.8810  1440.0      25.4
# 3671     Zimbabwe  2015      58.6      0.553       0.8810  1450.0      25.7
# 3672     Zimbabwe  2016      59.2      0.558       0.7710  1430.0      26.1
# 3673     Zimbabwe  2017      59.9      0.563       0.8450  1480.0      26.6
# 3674     Zimbabwe  2018      60.6      0.569       0.8500  1510.0      27.2
#
#       custom
# 0          0
# 1          1
# 2          2
# 3          3
# 4          4
# ...      ...
# 3670    3670
# 3671    3671
# 3672    3672
# 3673    3673
# 3674    3674
#
# [3675 rows x 8 columns]

# %%
df.drop(["custom","total_gdp"],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 df.drop(["custom","total_gdp"],axis=1,inplace=True)
#
# File c:\Users\anura\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\frame.py:6300, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6296                 weight  250.0   150.0
#    6297         falcon  speed   320.0   250.0
#    6298                 weight  1.0     0.8
#    6299         """
# -> 6300         return super().drop(
#    6301             labels=labels,
#    6302             axis=axis,
#    6303             index=index,
#
# File c:\Users\anura\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\generic.py:4644, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4640         obj = self
#    4641
#    4642         for axis, labels in axes.items():
#    4643             if labels is not None:
# -> 4644                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4645
#    4646         if inplace:
#    4647             self._update_inplace(obj)
#
# File c:\Users\anura\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\generic.py:4686, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4682                 if not isinstance(axis, MultiIndex):
#    4683                     raise AssertionError("axis must be a MultiIndex")
#    4684                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4685             else:
# -> 4686                 new_axis = axis.drop(labels, errors=errors)
#    4687             indexer = axis.get_indexer(new_axis)
#    4688
#    4689         # Case for non-unique axis
#
# File c:\Users\anura\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\indexes\base.py:7268, in Index.drop(self, labels, errors)
#    7266 if mask.any():
#    7267     if errors != "ignore":
# -> 7268         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7269     indexer = indexer[~mask]
#    7270 return self.delete(indexer)
#
# KeyError: "['total_gdp'] not found in axis"

# %%
df
# Out:
#           Country  year  life_exp  hdi_index  co2_consump     gdp  services
# 0     Afghanistan  1998      53.3      0.344       0.0522     NaN      24.4
# 1     Afghanistan  1999      54.7      0.348       0.0402     NaN      24.6
# 2     Afghanistan  2000      54.7      0.350       0.0370     NaN      24.7
# 3     Afghanistan  2001      54.8      0.353       0.0376     NaN      24.7
# 4     Afghanistan  2002      55.5      0.384       0.0471   333.0      25.6
# ...           ...   ...       ...        ...          ...     ...       ...
# 3670     Zimbabwe  2014      58.0      0.547       0.8810  1440.0      25.4
# 3671     Zimbabwe  2015      58.6      0.553       0.8810  1450.0      25.7
# 3672     Zimbabwe  2016      59.2      0.558       0.7710  1430.0      26.1
# 3673     Zimbabwe  2017      59.9      0.563       0.8450  1480.0      26.6
# 3674     Zimbabwe  2018      60.6      0.569       0.8500  1510.0      27.2
#
# [3675 rows x 7 columns]

# %% [markdown]
# # Rows Operations

# %%
ser = df["country"]
ser
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 3670       Zimbabwe
# 3671       Zimbabwe
# 3672       Zimbabwe
# 3673       Zimbabwe
# 3674       Zimbabwe
# Name: country, Length: 3675, dtype: str

# %%
#indexing
ser[5]
# Out:
# 'Afghanistan'

# %%
# Slicing
ser[4:16]
# Out:
# 4     Afghanistan
# 5     Afghanistan
# 6     Afghanistan
# 7     Afghanistan
# 8     Afghanistan
# 9     Afghanistan
# 10    Afghanistan
# 11    Afghanistan
# 12    Afghanistan
# 13    Afghanistan
# 14    Afghanistan
# 15    Afghanistan
# Name: country, dtype: str

# %%
ser.index
# Out:
# RangeIndex(start=0, stop=3675, step=1)

# %%
import numpy as np 
ser.index = np.arange(1,df.shape[0]+1,1)

# %%
ser
# Out:
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
# 5       Afghanistan
#            ...
# 3671       Zimbabwe
# 3672       Zimbabwe
# 3673       Zimbabwe
# 3674       Zimbabwe
# 3675       Zimbabwe
# Name: country, Length: 3675, dtype: str

# %% [markdown]
# # Implicit and Explicit Indices

# %%
# Provided from outside  => Explicit Indices/ Row Label
# Already Present => Implicit Indices always start from 0

# %%
ser.index[1] # Beacause everything increment by 1 using explicit Indexes
# Out:
# np.int64(2)

# %%
data = pd.Series(["a","b","c"],index=[1,5,3])
data #1 5 3 is label
# Out:
# 1    a
# 5    b
# 3    c
# dtype: str

# %%
data[1]
data[1:3] # Slicing byDefault Using Implicit Indexing or Positional Indices
# Out:
# 5    b
# 3    c
# dtype: str

# %%
data = pd.Series(["a","b","c"],index=["x","y","z"])

# %%
data
# Out:
# x    a
# y    b
# z    c
# dtype: str

# %%
data[:1]
# Out:
# x    a
# dtype: str

# %%
data["x"]
# Out:
# 'a'

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# data

# %%
df.iloc[-1] # reverse index
df.loc[-1] # Gives Error
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\anura\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\indexes\range.py:521, in RangeIndex.get_loc(self, key)
#     520 try:
# --> 521     return self._range.index(new_key)
#     522 except ValueError as err:
#
# ValueError: range.index(x): x not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[68], line 2
#       1 df.iloc[-1] # reverse index
# ----> 2 df.loc[-1]
#
# File c:\Users\anura\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\indexing.py:1207, in _LocationIndexer.__getitem__(self, key)
#    1205 maybe_callable = com.apply_if_callable(key, self.obj)
#    1206 maybe_callable = self._raise_callable_usage(key, maybe_callable)
# -> 1207 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\anura\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\indexing.py:1449, in _LocIndexer._getitem_axis(self, key, axis)
#    1447 # fall thru to straight lookup
#    1448 self._validate_key(key, axis)
# -> 1449 return self._get_label(key, axis=axis)
#
# File c:\Users\anura\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\indexing.py:1399, in _LocIndexer._get_label(self, label, axis)
#    1397 def _get_label(self, label, axis: AxisInt):
#    1398     # GH#5567 this will fail if the label is not present in the axis.
# -> 1399     return self.obj.xs(label, axis=axis)
#
# File c:\Users\anura\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\generic.py:4253, in NDFrame.xs(self, key, axis, level, drop_level)
#    4249                     new_index = index[loc : loc + 1]
#    4250                 else:
#    4251                     new_index = index[loc]
#    4252         else:
# -> 4253             loc = index.get_loc(key)
#    4254
#    4255             if isinstance(loc, np.ndarray):
#    4256                 if loc.dtype == np.bool_:
#
# File c:\Users\anura\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\indexes\range.py:523, in RangeIndex.get_loc(self, key)
#     521         return self._range.index(new_key)
#     522     except ValueError as err:
# --> 523         raise KeyError(key) from err
#     524 if isinstance(key, Hashable):
#     525     raise KeyError(key)
#
# KeyError: -1

# %%
temp = df.set_index("country")

# %%
temp["life_exp"]
# Out:
# country
# Afghanistan    53.3
# Afghanistan    54.7
# Afghanistan    54.7
# Afghanistan    54.8
# Afghanistan    55.5
#                ...
# Zimbabwe       58.0
# Zimbabwe       58.6
# Zimbabwe       59.2
# Zimbabwe       59.9
# Zimbabwe       60.6
# Name: life_exp, Length: 3675, dtype: float64

# %%
temp["life_exp"].loc["Zimbabwe"]
# Out:
# country
# Zimbabwe    49.7
# Zimbabwe    48.5
# Zimbabwe    47.5
# Zimbabwe    47.0
# Zimbabwe    46.6
# Zimbabwe    46.4
# Zimbabwe    46.4
# Zimbabwe    46.8
# Zimbabwe    47.4
# Zimbabwe    48.2
# Zimbabwe    48.9
# Zimbabwe    50.2
# Zimbabwe    52.3
# Zimbabwe    54.4
# Zimbabwe    56.0
# Zimbabwe    57.2
# Zimbabwe    58.0
# Zimbabwe    58.6
# Zimbabwe    59.2
# Zimbabwe    59.9
# Zimbabwe    60.6
# Name: life_exp, dtype: float64

# %%
# How to Add A Row to a dataframe

d = {'country':"India",'continent':"Asia","year":2000,"life_exp":37.08,"hdi_index":27.08,	"co2_consump":5.62,"gdp":100,"services":25.69}

# %%
df = pd.concat([df, pd.DataFrame([d])], ignore_index=True)

# %%
df
# Out:
#           country  year  life_exp  hdi_index  co2_consump     gdp  services  \
# 0     Afghanistan  1998     53.30      0.344       0.0522     NaN     24.40
# 1     Afghanistan  1999     54.70      0.348       0.0402     NaN     24.60
# 2     Afghanistan  2000     54.70      0.350       0.0370     NaN     24.70
# 3     Afghanistan  2001     54.80      0.353       0.0376     NaN     24.70
# 4     Afghanistan  2002     55.50      0.384       0.0471   333.0     25.60
# ...           ...   ...       ...        ...          ...     ...       ...
# 3672     Zimbabwe  2016     59.20      0.558       0.7710  1430.0     26.10
# 3673     Zimbabwe  2017     59.90      0.563       0.8450  1480.0     26.60
# 3674     Zimbabwe  2018     60.60      0.569       0.8500  1510.0     27.20
# 3675        India  2000     37.08     27.080       5.6200   100.0     25.69
# 3676        India  2000     37.08     27.080       5.6200   100.0     25.69
#
#       custom continent
# 0        0.0       NaN
# 1        1.0       NaN
# 2        2.0       NaN
# 3        3.0       NaN
# 4        4.0       NaN
# ...      ...       ...
# 3672  3672.0       NaN
# 3673  3673.0       NaN
# 3674  3674.0       NaN
# 3675     NaN      Asia
# 3676     NaN      Asia
#
# [3677 rows x 9 columns]

# %%
df.loc[len(df.index)] = [
    "India",
    2025,
    70.5,
    0.75,
    2.5,
    3000,
    55.2,
    3677,
    "Asia"
]

# %%
df
# Out:
#           country  year  life_exp  hdi_index  co2_consump     gdp  services  \
# 0     Afghanistan  1998     53.30      0.344       0.0522     NaN     24.40
# 1     Afghanistan  1999     54.70      0.348       0.0402     NaN     24.60
# 2     Afghanistan  2000     54.70      0.350       0.0370     NaN     24.70
# 3     Afghanistan  2001     54.80      0.353       0.0376     NaN     24.70
# 4     Afghanistan  2002     55.50      0.384       0.0471   333.0     25.60
# ...           ...   ...       ...        ...          ...     ...       ...
# 3673     Zimbabwe  2017     59.90      0.563       0.8450  1480.0     26.60
# 3674     Zimbabwe  2018     60.60      0.569       0.8500  1510.0     27.20
# 3675        India  2000     37.08     27.080       5.6200   100.0     25.69
# 3676        India  2000     37.08     27.080       5.6200   100.0     25.69
# 3677        India  2025     70.50      0.750       2.5000  3000.0     55.20
#
#       custom continent
# 0        0.0       NaN
# 1        1.0       NaN
# 2        2.0       NaN
# 3        3.0       NaN
# 4        4.0       NaN
# ...      ...       ...
# 3673  3673.0       NaN
# 3674  3674.0       NaN
# 3675     NaN      Asia
# 3676     NaN      Asia
# 3677  3677.0      Asia
#
# [3678 rows x 9 columns]

# %%
df.iloc[len(df.index)] = [
    "India",
    2025,
    70.5,
    0.75,
    2.5,
    3000,
    55.2,
    3677,
    "Asia"
] # This is not Possible because len(df.index) is not there
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 df.iloc[len(df.index)] = [
#       2     "India",
#       3     2025,
#       4     70.5,
#
# File c:\Users\anura\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\indexing.py:933, in _LocationIndexer.__setitem__(self, key, value)
#     931     key = self._raise_callable_usage(key, maybe_callable)
#     932 indexer = self._get_setitem_indexer(key)
# --> 933 self._has_valid_setitem_indexer(key)
#     935 iloc: _iLocIndexer = (
#     936     cast("_iLocIndexer", self) if self.name == "iloc" else self.obj.iloc
#     937 )
#     938 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File c:\Users\anura\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\indexing.py:1667, in _iLocIndexer._has_valid_setitem_indexer(self, indexer)
#    1665 elif is_integer(i):
#    1666     if i >= len(ax):
# -> 1667         raise IndexError("iloc cannot enlarge its target object")
#    1668 elif isinstance(i, dict):
#    1669     raise IndexError("iloc cannot enlarge its target object")
#
# IndexError: iloc cannot enlarge its target object

# %%
# drop rows
df.duplicated() #mask
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3673    False
# 3674    False
# 3675    False
# 3676     True
# 3677    False
# Length: 3678, dtype: bool

# %%
df
# Out:
#           country  year  life_exp  hdi_index  co2_consump     gdp  services  \
# 0     Afghanistan  1998     53.30      0.344       0.0522     NaN     24.40
# 1     Afghanistan  1999     54.70      0.348       0.0402     NaN     24.60
# 2     Afghanistan  2000     54.70      0.350       0.0370     NaN     24.70
# 3     Afghanistan  2001     54.80      0.353       0.0376     NaN     24.70
# 4     Afghanistan  2002     55.50      0.384       0.0471   333.0     25.60
# ...           ...   ...       ...        ...          ...     ...       ...
# 3673     Zimbabwe  2017     59.90      0.563       0.8450  1480.0     26.60
# 3674     Zimbabwe  2018     60.60      0.569       0.8500  1510.0     27.20
# 3675        India  2000     37.08     27.080       5.6200   100.0     25.69
# 3676        India  2000     37.08     27.080       5.6200   100.0     25.69
# 3677        India  2025     70.50      0.750       2.5000  3000.0     55.20
#
#       custom continent
# 0        0.0       NaN
# 1        1.0       NaN
# 2        2.0       NaN
# 3        3.0       NaN
# 4        4.0       NaN
# ...      ...       ...
# 3673  3673.0       NaN
# 3674  3674.0       NaN
# 3675     NaN      Asia
# 3676     NaN      Asia
# 3677  3677.0      Asia
#
# [3678 rows x 9 columns]

# %%
df.loc[df.duplicated()]
# Out:
#      country  year  life_exp  hdi_index  co2_consump    gdp  services  custom  \
# 3676   India  2000     37.08      27.08         5.62  100.0     25.69     NaN
#
#      continent
# 3676      Asia

# %%
df.drop_duplicates(keep="last")
df.drop_duplicates(keep="first")
df.drop_duplicates(keep=False)  # Remove all duplicate rows

# first last False  Keep the Particular Row
# Out:
#           country  year  life_exp  hdi_index  co2_consump     gdp  services  \
# 0     Afghanistan  1998      53.3      0.344       0.0522     NaN      24.4
# 1     Afghanistan  1999      54.7      0.348       0.0402     NaN      24.6
# 2     Afghanistan  2000      54.7      0.350       0.0370     NaN      24.7
# 3     Afghanistan  2001      54.8      0.353       0.0376     NaN      24.7
# 4     Afghanistan  2002      55.5      0.384       0.0471   333.0      25.6
# ...           ...   ...       ...        ...          ...     ...       ...
# 3671     Zimbabwe  2015      58.6      0.553       0.8810  1450.0      25.7
# 3672     Zimbabwe  2016      59.2      0.558       0.7710  1430.0      26.1
# 3673     Zimbabwe  2017      59.9      0.563       0.8450  1480.0      26.6
# 3674     Zimbabwe  2018      60.6      0.569       0.8500  1510.0      27.2
# 3677        India  2025      70.5      0.750       2.5000  3000.0      55.2
#
#       custom continent
# 0        0.0       NaN
# 1        1.0       NaN
# 2        2.0       NaN
# 3        3.0       NaN
# 4        4.0       NaN
# ...      ...       ...
# 3671  3671.0       NaN
# 3672  3672.0       NaN
# 3673  3673.0       NaN
# 3674  3674.0       NaN
# 3677  3677.0      Asia
#
# [3676 rows x 9 columns]

# %%
# delete the rows
df.drop(1,axis=0,inplace=True) # Row Label Not Change

# %%
df.loc[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\anura\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:2761, in pandas._libs.hashtable.Int64HashTable.get_item()
# -> 2761 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:2785, in pandas._libs.hashtable.Int64HashTable.get_item()
# -> 2785 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[97], line 1
# ----> 1 df.loc[1]
#
# File c:\Users\anura\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\indexing.py:1207, in _LocationIndexer.__getitem__(self, key)
#    1205 maybe_callable = com.apply_if_callable(key, self.obj)
#    1206 maybe_callable = self._raise_callable_usage(key, maybe_callable)
# -> 1207 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\anura\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\indexing.py:1449, in _LocIndexer._getitem_axis(self, key, axis)
#    1447 # fall thru to straight lookup
#    1448 self._validate_key(key, axis)
# -> 1449 return self._get_label(key, axis=axis)
#
# File c:\Users\anura\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\indexing.py:1399, in _LocIndexer._get_label(self, label, axis)
#    1397 def _get_label(self, label, axis: AxisInt):
#    1398     # GH#5567 this will fail if the label is not present in the axis.
# -> 1399     return self.obj.xs(label, axis=axis)
#
# File c:\Users\anura\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\generic.py:4253, in NDFrame.xs(self, key, axis, level, drop_level)
#    4249                     new_index = index[loc : loc + 1]
#    4250                 else:
#    4251                     new_index = index[loc]
#    4252         else:
# -> 4253             loc = index.get_loc(key)
#    4254
#    4255             if isinstance(loc, np.ndarray):
#    4256                 if loc.dtype == np.bool_:
#
# File c:\Users\anura\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\indexes\base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 1

# %%
df
# Out:
#           country  year  life_exp  hdi_index  co2_consump     gdp  services  \
# 0     Afghanistan  1998     53.30      0.344       0.0522     NaN     24.40
# 2     Afghanistan  2000     54.70      0.350       0.0370     NaN     24.70
# 3     Afghanistan  2001     54.80      0.353       0.0376     NaN     24.70
# 4     Afghanistan  2002     55.50      0.384       0.0471   333.0     25.60
# 5     Afghanistan  2003     56.50      0.393       0.0509   346.0     25.90
# ...           ...   ...       ...        ...          ...     ...       ...
# 3673     Zimbabwe  2017     59.90      0.563       0.8450  1480.0     26.60
# 3674     Zimbabwe  2018     60.60      0.569       0.8500  1510.0     27.20
# 3675        India  2000     37.08     27.080       5.6200   100.0     25.69
# 3676        India  2000     37.08     27.080       5.6200   100.0     25.69
# 3677        India  2025     70.50      0.750       2.5000  3000.0     55.20
#
#       custom continent
# 0        0.0       NaN
# 2        2.0       NaN
# 3        3.0       NaN
# 4        4.0       NaN
# 5        5.0       NaN
# ...      ...       ...
# 3673  3673.0       NaN
# 3674  3674.0       NaN
# 3675     NaN      Asia
# 3676     NaN      Asia
# 3677  3677.0      Asia
#
# [3677 rows x 9 columns]

# %%
df.iloc[1]
# Out:
# country        Afghanistan
# year                  2000
# life_exp              54.7
# hdi_index             0.35
# co2_consump          0.037
# gdp                    NaN
# services              24.7
# custom                 2.0
# continent              NaN
# Name: 2, dtype: object

# %%
df.iloc[1:5,0:4]
# Out:
#        country  year  life_exp  hdi_index
# 2  Afghanistan  2000      54.7      0.350
# 3  Afghanistan  2001      54.8      0.353
# 4  Afghanistan  2002      55.5      0.384
# 5  Afghanistan  2003      56.5      0.393

# %%
df.loc[1:5,0:4] # This will not work because  loc p=work on positional indexes and

# %%
df.loc[1:5,["country","life_exp"]]  # This will not work because  loc p=work on positional indexes and 

# slicing in loc include last position
# Out:
#        country  life_exp
# 2  Afghanistan      54.7
# 3  Afghanistan      54.8
# 4  Afghanistan      55.5
# 5  Afghanistan      56.5

# %%
df.loc[1:5,"year":"life_exp"]  # This will not work because  loc p=work on positional indexes and
# Out:
#    year  life_exp
# 2  2000      54.7
# 3  2001      54.8
# 4  2002      55.5
# 5  2003      56.5

# %%
df.iloc[1:10:2] # ek se 9 tak implicit indexing and 2 ka jump
# Out:
#         country  year  life_exp  hdi_index  co2_consump    gdp  services  \
# 2   Afghanistan  2000      54.7      0.350       0.0370    NaN      24.7
# 4   Afghanistan  2002      55.5      0.384       0.0471  333.0      25.6
# 6   Afghanistan  2004      57.1      0.409       0.0368  336.0      26.1
# 8   Afghanistan  2006      58.0      0.429       0.0622  368.0      26.9
# 10  Afghanistan  2008      59.2      0.447       0.1520  415.0      28.2
#
#     custom continent
# 2      2.0       NaN
# 4      4.0       NaN
# 6      6.0       NaN
# 8      8.0       NaN
# 10    10.0       NaN

# %%
df.iloc[29:40,-3:]
# Out:
#     services  custom continent
# 30      37.5    30.0       NaN
# 31      37.6    31.0       NaN
# 32      36.0    32.0       NaN
# 33      37.3    33.0       NaN
# 34      35.7    34.0       NaN
# 35      36.7    35.0       NaN
# 36      38.9    36.0       NaN
# 37      40.0    37.0       NaN
# 38      40.1    38.0       NaN
# 39      40.6    39.0       NaN
# 40      42.5    40.0       NaN

# %%
df["life_exp"].mean()
df["life_exp"].sum()
df["life_exp"].count()
# Out:
# np.int64(3677)

# %%
# Sorting

# %%
df
# Out:
#           country  year  life_exp  hdi_index  co2_consump     gdp  services  \
# 0     Afghanistan  1998     53.30      0.344       0.0522     NaN     24.40
# 2     Afghanistan  2000     54.70      0.350       0.0370     NaN     24.70
# 3     Afghanistan  2001     54.80      0.353       0.0376     NaN     24.70
# 4     Afghanistan  2002     55.50      0.384       0.0471   333.0     25.60
# 5     Afghanistan  2003     56.50      0.393       0.0509   346.0     25.90
# ...           ...   ...       ...        ...          ...     ...       ...
# 3673     Zimbabwe  2017     59.90      0.563       0.8450  1480.0     26.60
# 3674     Zimbabwe  2018     60.60      0.569       0.8500  1510.0     27.20
# 3675        India  2000     37.08     27.080       5.6200   100.0     25.69
# 3676        India  2000     37.08     27.080       5.6200   100.0     25.69
# 3677        India  2025     70.50      0.750       2.5000  3000.0     55.20
#
#       custom continent
# 0        0.0       NaN
# 2        2.0       NaN
# 3        3.0       NaN
# 4        4.0       NaN
# 5        5.0       NaN
# ...      ...       ...
# 3673  3673.0       NaN
# 3674  3674.0       NaN
# 3675     NaN      Asia
# 3676     NaN      Asia
# 3677  3677.0      Asia
#
# [3677 rows x 9 columns]

# %%
df.sort_values(["year"])
# Out:
#          country  year  life_exp  hdi_index  co2_consump      gdp  services  \
# 42       Algeria  1998      70.2      0.621        3.530   2990.0      52.0
# 21       Albania  1998      74.8      0.655        0.563   1600.0      33.0
# 2457      Norway  1998      78.5      0.904        9.500  64900.0      72.5
# 1239     Georgia  1998      70.6        NaN        1.080   1440.0      41.3
# 2100  Mauritania  1998      62.6      0.459        0.429   1370.0      40.0
# ...          ...   ...       ...        ...          ...      ...       ...
# 83        Angola  2018      64.6      0.582        1.120   3600.0      42.1
# 62       Algeria  2018      76.0      0.746        3.690   4160.0      59.6
# 3674    Zimbabwe  2018      60.6      0.569        0.850   1510.0      27.2
# 3653      Zambia  2018      62.5      0.582        0.302   1370.0      39.3
# 3677       India  2025      70.5      0.750        2.500   3000.0      55.2
#
#       custom continent
# 42      42.0       NaN
# 21      21.0       NaN
# 2457  2457.0       NaN
# 1239  1239.0       NaN
# 2100  2100.0       NaN
# ...      ...       ...
# 83      83.0       NaN
# 62      62.0       NaN
# 3674  3674.0       NaN
# 3653  3653.0       NaN
# 3677  3677.0      Asia
#
# [3677 rows x 9 columns]

# %%
df.sort_values(["year"],ascending=False)
# Out:
#           country  year  life_exp  hdi_index  co2_consump     gdp  services  \
# 3677        India  2025      70.5      0.750       2.5000  3000.0      55.2
# 3653       Zambia  2018      62.5      0.582       0.3020  1370.0      39.3
# 1595         Iraq  2018      73.3      0.671       5.3200  4790.0      58.4
# 20    Afghanistan  2018      62.7      0.509       0.2540   569.0      38.4
# 587      Cameroon  2018      62.6      0.560       0.3230  1380.0      41.4
# ...           ...   ...       ...        ...          ...     ...       ...
# 21        Albania  1998      74.8      0.655       0.5630  1600.0      33.0
# 3612        Yemen  1998      62.5      0.431       0.7340  2290.0      41.1
# 1575         Iraq  1998      67.9      0.583       3.2600  3350.0      50.7
# 3654     Zimbabwe  1998      49.7      0.442       1.2000  1780.0      27.9
# 0     Afghanistan  1998      53.3      0.344       0.0522     NaN      24.4
#
#       custom continent
# 3677  3677.0      Asia
# 3653  3653.0       NaN
# 1595  1595.0       NaN
# 20      20.0       NaN
# 587    587.0       NaN
# ...      ...       ...
# 21      21.0       NaN
# 3612  3612.0       NaN
# 1575  1575.0       NaN
# 3654  3654.0       NaN
# 0        0.0       NaN
#
# [3677 rows x 9 columns]

# %%
df.sort_values(["life_exp"])
# Out:
#         country  year  life_exp  hdi_index  co2_consump      gdp  services  \
# 1419      Haiti  2010     32.50      0.471        0.211   1290.0     59.90
# 3676      India  2000     37.08     27.080        5.620    100.0     25.69
# 3675      India  2000     37.08     27.080        5.620    100.0     25.69
# 1098   Eswatini  2004     43.10      0.445        1.010   2750.0     54.00
# 1099   Eswatini  2005     43.30      0.456        1.000   2900.0     54.80
# ...         ...   ...       ...        ...          ...      ...       ...
# 1698      Japan  2016     84.50      0.912        9.450  35300.0     71.80
# 2918  Singapore  2018     84.70      0.936        7.100  61100.0     84.00
# 1699      Japan  2017     84.70      0.915        9.330  35900.0     71.90
# 2917  Singapore  2017     84.70      0.933        7.110  59300.0     83.50
# 1700      Japan  2018     84.80      0.917        9.140  36200.0     72.10
#
#       custom continent
# 1419  1419.0       NaN
# 3676     NaN      Asia
# 3675     NaN      Asia
# 1098  1098.0       NaN
# 1099  1099.0       NaN
# ...      ...       ...
# 1698  1698.0       NaN
# 2918  2918.0       NaN
# 1699  1699.0       NaN
# 2917  2917.0       NaN
# 1700  1700.0       NaN
#
# [3677 rows x 9 columns]

# %%
df.sort_values(["life_exp"],ascending=False)
# Out:
#         country  year  life_exp  hdi_index  co2_consump      gdp  services  \
# 1700      Japan  2018     84.80      0.917        9.140  36200.0     72.10
# 2917  Singapore  2017     84.70      0.933        7.110  59300.0     83.50
# 1699      Japan  2017     84.70      0.915        9.330  35900.0     71.90
# 2918  Singapore  2018     84.70      0.936        7.100  61100.0     84.00
# 1698      Japan  2016     84.50      0.912        9.450  35300.0     71.80
# ...         ...   ...       ...        ...          ...      ...       ...
# 1099   Eswatini  2005     43.30      0.456        1.000   2900.0     54.80
# 1098   Eswatini  2004     43.10      0.445        1.010   2750.0     54.00
# 3675      India  2000     37.08     27.080        5.620    100.0     25.69
# 3676      India  2000     37.08     27.080        5.620    100.0     25.69
# 1419      Haiti  2010     32.50      0.471        0.211   1290.0     59.90
#
#       custom continent
# 1700  1700.0       NaN
# 2917  2917.0       NaN
# 1699  1699.0       NaN
# 2918  2918.0       NaN
# 1698  1698.0       NaN
# ...      ...       ...
# 1099  1099.0       NaN
# 1098  1098.0       NaN
# 3675     NaN      Asia
# 3676     NaN      Asia
# 1419  1419.0       NaN
#
# [3677 rows x 9 columns]

# %%
# Sort the data by year and than life exp
df.sort_values(["year","life_exp"],ascending=[False,True])
# Out:
#                        country  year  life_exp  hdi_index  co2_consump  \
# 3677                     India  2025      70.5      0.750       2.5000
# 1889                   Lesotho  2018      51.4      0.522       1.2600
# 650   Central African Republic  2018      51.5      0.395       0.0651
# 1112                  Eswatini  2018      57.8      0.605       1.0600
# 2267                Mozambique  2018      57.9      0.452       0.2810
# ...                        ...   ...       ...        ...          ...
# 1491                   Iceland  1998      79.5      0.855       9.5800
# 1449          Hong Kong, China  1998      79.6      0.820       6.0700
# 3171                    Sweden  1998      79.6      0.894       6.6200
# 3192               Switzerland  1998      79.9      0.882       6.3000
# 1680                     Japan  1998      81.0      0.849       9.4900
#
#           gdp  services  custom continent
# 3677   3000.0      55.2  3677.0      Asia
# 1889   1110.0      41.6  1889.0       NaN
# 650     413.0      23.4   650.0       NaN
# 1112   3780.0      63.8  1112.0       NaN
# 2267    603.0      21.0  2267.0       NaN
# ...       ...       ...     ...       ...
# 1491  39600.0      64.7  1491.0       NaN
# 1449  24900.0      77.2  1449.0       NaN
# 3171  37700.0      71.1  3171.0       NaN
# 3192  70700.0      70.2  3192.0       NaN
# 1680  30800.0      62.5  1680.0       NaN
#
# [3677 rows x 9 columns]

# %%
# How to create Dataframe from Scratch

df.loc[0]
# Out:
# country        Afghanistan
# year                  1998
# life_exp              53.3
# hdi_index            0.344
# co2_consump         0.0522
# gdp                    NaN
# services              24.4
# custom                 0.0
# continent              NaN
# Name: 0, dtype: object

# %%
pd.Series([10,20,30],index=["a","b","c"])
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
# Dataframe
# Approach 1 : Row Oriented
# Approach 2 : Col Oriented

# %%
pd.DataFrame([[10,20],[30,40]],columns=["A","B"])
# Out:
#     A   B
# 0  10  20
# 1  30  40

# %%
pd.DataFrame({"A":[10,30],"B":[20,40]})
# Out:
#     A   B
# 0  10  20
# 1  30  40
