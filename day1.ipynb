# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# # Basic Programming

# %%
print(5+2)
# Out:
# 7

# %%
5+2
# Out:
# 7

# %% [markdown]
# ## Simple Interest

# %%
p = 100
r = 5
t = 2
si = (p*r*t)/100
print("The Simple Interest is",si)
# Out:
# The Simple Interest is 10.0

# %% [markdown]
# # Input

# %%
name = input()
print("Hello My Name is",name)
# Out:
# Hello My Name is AJ

# %% [markdown]
# ## Data Type

# %%
print(type(10))
print(type('a'))
print(type("AJ"))
print(type(10.56))
print(type(True))
print(type(None)) # None is same as null
print('Clark Kent\'s awesome')

# Python don't have size for int or float 
b = 45564451212313212121313213212113213215656565656565656 
print(b)

# Comments
# Out:
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'float'>
# <class 'bool'>
# <class 'NoneType'>
# Clark Kent's awesome
# 45564451212313212121313213212113213215656565656565656

# %%
# Float to int
f = 7.4
i = int(f)
print(i)
# Int to String
s = str(i)
print(type(s),s)
# Float to string 
print(type(str(f)),str(f))
#int to float
print(float(i))

# String to int direct conversion is not possible with floating Number
str2  = "45.56"
print(int(float(str2)))
# Out:
# 7
# <class 'str'> 7
# <class 'str'> 7.4
# 7.0
# 45

# %%
a = 5
b = 4
print(a+b)
print(a-b)
print(a*b)
print(a/b)  # for float value
print(a//b) # for integer output
print(a%b) 

print(a**b)
x = a**(1/2)
print(f'{x:.4f}')
# Out:
# 9
# 1
# 20
# 1.25
# 1
# 1
# 625
# 2.2361

# %%
print(2 and 2.5) 
print(2 or 2.5)
# Out:
# 2.5
# 2
